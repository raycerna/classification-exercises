# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pydataset import data
import statistics as stats

# %% [markdown]
# ### Exercise 4
# In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets)
# containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.
#
# - print the first 3 rows
#
# - print the number of rows and columns (shape)
#
# - print the column names
#
# - print the data type of each column
#
# - print the summary statistics for each of the numeric variables

# %%
iris = data('iris')
iris.head(3)  #print first three rows
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
iris.shape #print number of rows and columns
# Out:
# (150, 5)

# %%
print(iris.columns) #print the column names
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
iris.dtypes #print the data type of each column
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
iris.describe() #print summary statistics
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### 5
#
# Read the Table1_CustDetails table from your spreadsheet exercises google sheet into a dataframe named df_google_sheets.
#
# Make sure that the spreadsheet is publicly visible under your sharing settings.
#
# - assign the first 100 rows to a new dataframe, df_google_sheets_sample
# - print the number of rows of your original dataframe
# - print the first 5 column names
# - print the column names that have a data type of object
# - compute the range for each of the numeric variables.

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Z1PH2DMB0dDz864iRd4q6wmUZvil6_oyEeYw_0l7mlE/edit#gid=1023018493'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_google_sheets = pd.read_csv(csv_export_url)
df_google_sheets.head(100) #imported telco google sheet renamed to df_google_sheets, first 100 rows
# Out:
#    customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0   0002-ORFBO  Female                  0     Yes        Yes              1
# 1   0003-MKNFE    Male                  0      No         No              2
# 2   0004-TLHLJ    Male                  0      No         No              1
# 3   0011-IGKFF    Male                  1     Yes         No              1
# 4   0013-EXCHZ  Female                  1     Yes         No              1
# 5   0013-MHZWF  Female                  0      No        Yes              1
# 6   0013-SMEOE  Female                  1     Yes         No              1
# 7   0014-BMAQU    Male                  0     Yes         No              2
# 8   0015-UOCOJ  Female                  1      No         No              1
# 9   0016-QLJIS  Female                  0     Yes        Yes              2
# 10  0017-DINOC    Male                  0      No         No              0
# ...

# %%
df_google_sheets.shape[0] #print number of rows only [] instead of (), 0 for rows, 1 for columns
# Out:
# 7049

# %%
df_google_sheets.columns[0:5] #print the column titles for first five rows 0-5 or :5
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents'], dtype='object')

# %%
list(df_google_sheets.select_dtypes('object')) #print the column titles that are objects in a list
# Out:
# ['customer_id', 'gender', 'partner', 'dependents', 'payment_type', 'churn']

# %%
df_google_sheets.select_dtypes(include='object').columns.tolist() 
#alternative to listing specific column titles by type
# Out:
# ['customer_id', 'gender', 'partner', 'dependents', 'payment_type', 'churn']

# %%
df_google_sheets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7049 non-null   object
#  1   gender             7049 non-null   object
#  2   is_senior_citizen  7049 non-null   int64
#  3   partner            7049 non-null   object
#  4   dependents         7049 non-null   object
#  5   phone_service      7049 non-null   int64
#  6   internet_service   7049 non-null   int64
#  7   contract_type      7049 non-null   int64
#  8   payment_type       7049 non-null   object
#  9   monthly_charges    7049 non-null   float64
#  10  total_charges      7038 non-null   float64
#  11  churn              7049 non-null   object
#  12  tenure             7049 non-null   float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 716.0+ KB

# %%
numeric_dtypes = df_google_sheets.select_dtypes(include=['float64', 'int64'])
numeric_dtypes
# Out:
#       is_senior_citizen  phone_service  internet_service  contract_type  \
# 0                     0              1                 1              1
# 1                     0              2                 1              0
# 2                     0              1                 2              0
# 3                     1              1                 2              0
# 4                     1              1                 2              0
# ...                 ...            ...               ...            ...
# 7044                  0              1                 1              1
# 7045                  0              2                 2              0
# 7046                  0              1                 1              0
# 7047                  0              1                 1              2
# 7048                  0              0                 1              2
#
#       monthly_charges  total_charges  tenure
# 0               65.60         593.30     9.0
# ...

# %%
df_google_sheets.select_dtypes('number').apply(lambda col: col.max() - col.min()).rename('range')
# Out:
# is_senior_citizen       1.0
# phone_service           2.0
# internet_service        2.0
# contract_type           2.0
# monthly_charges       100.5
# total_charges        8666.0
# tenure                 79.3
# Name: range, dtype: float64

# %% [markdown]
# ### 6
#
# Download your spreadsheet exercises google sheet as an excel file (File → Download → Microsoft Excel).
# Read the Table1_CustDetails worksheet into a dataframe named df_excel.
#
# - assign the first 100 rows to a new dataframe, df_excel_sample
# - print the number of rows of your original dataframe
# - print the first 5 column names
# - print the column names that have a data type of object
# - compute the range for each of the numeric variables.

# %%
df_excel = pd.read_excel('/Users/Ray/Downloads/Copy of Copy of Raymond Cerna - jemison_spreadsheet_exercises.xlsx')

df_excel_sample = df_excel.head(100) #assigned first 100 rows to new dataframe

# %%
df_excel.shape[0] #print number of rows on original dataframe
# Out:
# 7049

# %%
df_excel_sample.shape[0] #print number of rows on new dataframe
# Out:
# 100

# %%
df_excel_sample.columns[:5] #print first five column names
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents'], dtype='object')

# %%
list(df_excel_sample.select_dtypes('object')) #print column names that have data type of object
# Out:
# ['customer_id', 'gender', 'partner', 'dependents', 'payment_type', 'churn']

# %%
df_excel_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        100 non-null    object
#  1   gender             100 non-null    object
#  2   is_senior_citizen  100 non-null    float64
#  3   partner            100 non-null    object
#  4   dependents         100 non-null    object
#  5   phone_service      100 non-null    float64
#  6   internet_service   100 non-null    float64
#  7   contract_type      100 non-null    float64
#  8   payment_type       100 non-null    object
#  9   monthly_charges    100 non-null    float64
#  10  total_charges      100 non-null    float64
#  11  churn              100 non-null    object
#  12  tenure             100 non-null    float64
# dtypes: float64(7), object(6)
# memory usage: 10.3+ KB

# %%
df_excel_sample.select_dtypes('number').apply(lambda col: col.max() - col.min()).rename('range')
#range of each numeric variable
# Out:
# is_senior_citizen       1.000000
# phone_service           2.000000
# internet_service        2.000000
# contract_type           2.000000
# monthly_charges        97.400000
# total_charges        8476.850000
# tenure                 73.177334
# Name: range, dtype: float64

# %% [markdown]
# ### 7
# Read the data from this google sheet into a dataframe, df_google.
#
# - print the first 3 rows
# - print the number of rows and columns
# - print the column names
# - print the data type of each column
# - print the summary statistics for each of the numeric variables
# - print the unique values for each of your categorical variables

# %%
sheet_url =  ('https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357')

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_google = pd.read_csv(csv_export_url)
df_google.head(3) #imported train google sheet renamed to df_google, first 3 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_google.shape #printed rows and columns
# Out:
# (891, 12)

# %%
df_google.columns #printed all column names
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_google.dtypes #printed data types of each column
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_google.info() #alternative way of printing data types of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_google.describe() #print summary statistics for each numeric column
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_google.describe().T #flip rows and columns to show summary statistics
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
for col in df_google:
    if df_google[col].dtypes != 'object':
        print(f'{col} has {df_google[col].nunique()} unique values.')

        #print unique values for categorical variables other than objects
# Out:
# PassengerId has 891 unique values.
# Survived has 2 unique values.
# Pclass has 3 unique values.
# Age has 88 unique values.
# SibSp has 7 unique values.
# Parch has 7 unique values.
# Fare has 248 unique values.

# %%
for col in df_google:
    if df_google[col].dtypes == 'object':
        print(f'{col} has {df_google[col].nunique()} unique values.')

        #print unique values for categorical variables in objects
# Out:
# Name has 891 unique values.
# Sex has 2 unique values.
# Ticket has 681 unique values.
# Cabin has 147 unique values.
# Embarked has 3 unique values.

# %%
for col in df_google:
    
        print(f'{col} has {df_google[col].nunique()} unique values.')

        #print unique values for all variables
# Out:
# PassengerId has 891 unique values.
# Survived has 2 unique values.
# Pclass has 3 unique values.
# Name has 891 unique values.
# Sex has 2 unique values.
# Age has 88 unique values.
# SibSp has 7 unique values.
# Parch has 7 unique values.
# Ticket has 681 unique values.
# Fare has 248 unique values.
# Cabin has 147 unique values.
# Embarked has 3 unique values.

# %%
import acquire

# %%
titanic_df = acquire.get_titanic_data()
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class deck  embark_town  alone
# 0        S  Third  NaN  Southampton      0
# 1        C  First    C    Cherbourg      0
# 2        S  Third  NaN  Southampton      1
# 3        S  First    C  Southampton      0
# 4        S  Third  NaN  Southampton      1

# %%
iris_df = acquire.get_iris_data()
iris_df.head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width  measurement_id
# 0          0.2               1
# 1          0.2               2
# 2          0.2               3
# 3          0.2               4
# 4          0.2               5

# %%
telco_df = acquire.get_telco_data()
telco_df.head()
# Out:
#                  contract_type_id  internet_service_type_id customer_id  \
# payment_type_id
# 2                               2                         1  0002-ORFBO
# 2                               1                         1  0003-MKNFE
# 1                               1                         2  0004-TLHLJ
# 1                               1                         2  0011-IGKFF
# 2                               1                         2  0013-EXCHZ
#
#                  gender  senior_citizen partner dependents  tenure  \
# payment_type_id
# 2                Female               0     Yes        Yes       9
# 2                  Male               0      No         No       9
# 1                  Male               0      No         No       4
# 1                  Male               1     Yes         No      13
# 2                Female               1     Yes         No       3
#
#                 phone_service multiple_lines  ... tech_support streaming_tv  \
# ...

# %% [markdown]
# ## Exercises
#
# The end product of this exercise should be the specified functions in a python script named `prepare.py`.
# Do these in your `classification_exercises.ipynb` first, then transfer to the prepare.py file.
#
# This work should all be saved in your local `classification-exercises` repo. Then add, commit, and push your changes.
#
# Using the Iris Data:
#
# 1. Use the function defined in `acquire.py` to load the iris data.
#
# 1. Drop the `species_id` and `measurement_id` columns.
#
# 1. Rename the `species_name` column to just `species`.
#
# 1. Create dummy variables of the species name.
#
# 1. Create a function named `prep_iris` that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
iris_df = acquire.get_iris_data()
iris_df.head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width  measurement_id
# 0          0.2               1
# 1          0.2               2
# 2          0.2               3
# 3          0.2               4
# 4          0.2               5

# %%
columns_to_drop = ['species_id', 'measurement_id']

# %%
iris_df = iris_df.drop(columns = columns_to_drop)

# %%
iris_df.head()
# Out:
#   species_name  sepal_length  sepal_width  petal_length  petal_width
# 0       setosa           5.1          3.5           1.4          0.2
# 1       setosa           4.9          3.0           1.4          0.2
# 2       setosa           4.7          3.2           1.3          0.2
# 3       setosa           4.6          3.1           1.5          0.2
# 4       setosa           5.0          3.6           1.4          0.2

# %%
iris_df = iris_df.rename(columns={'species_name': 'species'})
iris_df.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2

# %%
dummy_df = pd.get_dummies(iris_df[['species']], dummy_na=False)
dummy_df
# Out:
#      species_setosa  species_versicolor  species_virginica
# 0                 1                   0                  0
# 1                 1                   0                  0
# 2                 1                   0                  0
# 3                 1                   0                  0
# 4                 1                   0                  0
# 5                 1                   0                  0
# 6                 1                   0                  0
# 7                 1                   0                  0
# 8                 1                   0                  0
# 9                 1                   0                  0
# 10                1                   0                  0
# 11                1                   0                  0
# 12                1                   0                  0
# 13                1                   0                  0
# 14                1                   0                  0
# ...

# %%
iris_df = pd.concat([iris_df, dummy_df], axis=1)
iris_df
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width  \
# 0        setosa           5.1          3.5           1.4          0.2
# 1        setosa           4.9          3.0           1.4          0.2
# 2        setosa           4.7          3.2           1.3          0.2
# 3        setosa           4.6          3.1           1.5          0.2
# 4        setosa           5.0          3.6           1.4          0.2
# 5        setosa           5.4          3.9           1.7          0.4
# 6        setosa           4.6          3.4           1.4          0.3
# 7        setosa           5.0          3.4           1.5          0.2
# 8        setosa           4.4          2.9           1.4          0.2
# 9        setosa           4.9          3.1           1.5          0.1
# 10       setosa           5.4          3.7           1.5          0.2
# 11       setosa           4.8          3.4           1.6          0.2
# ...

# %%
def prep_iris(df):
    df = iris_df

# %%
def prep_iris(iris_df):
    '''
    Takes in a iris dataframe and returns a cleaned dataframe
    Arguments: df - a pandas dataframe with the expected feature names and columns
    Return: clean_df - a dataframe with the cleaning operations performed on it
    '''

    #Drop Columns
    columns_to_drop = ['species_id', 'measurement_id']
    iris_df = iris_df.drop(columns = columns_to_drop)
    #renamed column
    iris_df = iris_df.rename(columns={'species_name': 'species'})
    #Encoded categorical variables
    dummy_df = pd.get_dummies(iris_df[['species']], dummy_na=False)
    iris_df = pd.concat([iris_df, dummy_df], axis=1)
    return iris_df

# %%
iris_df = acquire.get_iris_data()
iris_df = prep_iris(iris_df)
iris_df.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width  \
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2
#
#    species_setosa  species_versicolor  species_virginica
# 0               1                   0                  0
# 1               1                   0                  0
# 2               1                   0                  0
# 3               1                   0                  0
# 4               1                   0                  0

# %% [markdown]
# ### Using the Titanic dataset
#
# 1. Use the function defined in acquire.py to load the Titanic data.
#
# 2. Drop any unnecessary, unhelpful, or duplicated columns.
#
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.
#
# 4. Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %%
titanic_df = acquire.get_titanic_data()
titanic_df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class deck  embark_town  alone
# 0        S  Third  NaN  Southampton      0
# 1        C  First    C    Cherbourg      0
# 2        S  Third  NaN  Southampton      1
# 3        S  First    C  Southampton      0
# 4        S  Third  NaN  Southampton      1

# %%
# Drop duplicates
titanic_df.drop_duplicates(inplace=True)

# %%
columns_to_drop = ['embarked', 'class', 'passenger_id', 'deck']

# %%
titanic_df = titanic_df.drop(columns = columns_to_drop)

# %%
dummy_df = pd.get_dummies(titanic_df[['sex', 'embark_town']], dummy_na=False, drop_first=[True, True])
dummy_df
# Out:
#      sex_male  embark_town_Queenstown  embark_town_Southampton
# 0           1                       0                        1
# 1           0                       0                        0
# 2           0                       0                        1
# 3           0                       0                        1
# 4           1                       0                        1
# ..        ...                     ...                      ...
# 886         1                       0                        1
# 887         0                       0                        1
# 888         0                       0                        1
# 889         1                       0                        0
# 890         1                       1                        0
#
# [891 rows x 3 columns]

# %%
titanic_df = pd.concat([titanic_df, dummy_df], axis=1)
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embark_town  \
# 0           0       3    male  22.0      1      0   7.2500  Southampton
# 1           1       1  female  38.0      1      0  71.2833    Cherbourg
# 2           1       3  female  26.0      0      0   7.9250  Southampton
# 3           1       1  female  35.0      1      0  53.1000  Southampton
# 4           0       3    male  35.0      0      0   8.0500  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 886         0       2    male  27.0      0      0  13.0000  Southampton
# 887         1       1  female  19.0      0      0  30.0000  Southampton
# 888         0       3  female   NaN      1      2  23.4500  Southampton
# 889         1       1    male  26.0      0      0  30.0000    Cherbourg
# 890         0       3    male  32.0      0      0   7.7500   Queenstown
#
#      alone  sex_male  embark_town_Queenstown  embark_town_Southampton
# ...

# %%
def prep_titanic(titanic_df):
    '''
    Takes in a titanic datafram and returns a cleaned dataframe
    Arguments: df - a pandas dataframe with the expected feature names and columns
    Return: clean_df - a dataframe with the cleaning operations performed on it
    '''
    #Drop duplicates
    titanic_df.drop_duplicates(inplace=True)
    #Drop Columns
    columns_to_drop = ['embarked', 'class', 'passenger_id', 'deck']
    titanic_df = titanic_df.drop(columns = columns_to_drop)
    #Encoded categorical variables
    dummy_df = pd.get_dummies(titanic_df[['sex', 'embark_town']], dummy_na=False, drop_first=[True, True])
    titanic_df = pd.concat([titanic_df, dummy_df], axis=1)
    return titanic_df.drop(columns=['sex', 'embark_town'])

# %%
titanic_df = acquire.get_titanic_data()
titanic_df = prep_titanic(titanic_df)
titanic_df.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare  alone  sex_male  \
# 0         0       3  22.0      1      0   7.2500      0         1
# 1         1       1  38.0      1      0  71.2833      0         0
# 2         1       3  26.0      0      0   7.9250      1         0
# 3         1       1  35.0      1      0  53.1000      0         0
# 4         0       3  35.0      0      0   8.0500      1         1
#
#    embark_town_Queenstown  embark_town_Southampton
# 0                       0                        1
# 1                       0                        0
# 2                       0                        1
# 3                       0                        1
# 4                       0                        1

# %% [markdown]
# ### Using the Telco dataset
#
# 1. Use the function defined in acquire.py to load the Telco data.
#
# 2. Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.
#
# 3. Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.
#
# 4. Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.
